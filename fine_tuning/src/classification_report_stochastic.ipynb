# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AAA/exp_final/
# Out:
# /content/drive/.shortcut-targets-by-id/1CgwA7FpvBMd6M6lLlD9Rv0X2nkT63Etq/AAA/exp_final

# %%
from sklearn.metrics import classification_report
import pandas as pd

# %%
df = pd.read_csv("exp_final_classification_results_stochastic.csv")

# %%
report = pd.DataFrame(classification_report( df["sarcastic"], df["stochastic_prediction_label"], zero_division=0, output_dict=True))
report
# Out:
#                    0           1  accuracy   macro avg  weighted avg
# precision   0.500000    0.922535  0.905405    0.711268      0.882566
# recall      0.214286    0.977612  0.905405    0.595949      0.905405
# f1-score    0.300000    0.949275  0.905405    0.624638      0.887857
# support    14.000000  134.000000  0.905405  148.000000    148.000000

# %%
report.to_csv("classification_report_stochastic.csv")

# %%
df["fluency"] = None
df["adequacy"] = None
df.to_csv("manual_check_stochastic.csv")
